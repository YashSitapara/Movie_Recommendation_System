# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ## Simple Recommendation System
# #### Returns the top 250 movies, based on the gnere you type during the search

# %%
mdata = pd.read_csv('./movies_metadata.csv')
mdata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
mdata['genres'] = mdata['genres'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
mdata.genres
# Out:
# 0         [Animation, Comedy, Family]
# 1        [Adventure, Fantasy, Family]
# 2                   [Romance, Comedy]
# 3            [Comedy, Drama, Romance]
# 4                            [Comedy]
#                      ...
# 45461                 [Drama, Family]
# 45462                         [Drama]
# 45463       [Action, Drama, Thriller]
# 45464                              []
# 45465                              []
# Name: genres, Length: 45466, dtype: object

# %%
mdata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
# We will use the Weighted Average formula : (v/(v+m) * R) + (m/(m+v) * C)
# v = No. of votes for the movie
# m = Min. votes required to be listed in the chart
# R = Avg. rating of the movie
# C = Mean vote across the whole report

# %%
# For m, for a movie to feature in the charts, it must have more votes than at least 95% of the movies in the list.
m = mdata[mdata.vote_count.notnull()].vote_count.astype('int').quantile(0.95)
C = mdata[mdata.vote_average.notnull()].vote_average.mean()
print("m : ", m, " and c : ", C)
# Out:
# m :  434.0  and c :  5.618207215134184

# %%
# Adding a Column with Year
mdata['year'] = pd.to_datetime(mdata.release_date, errors = 'coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)
mdata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
#
#                                             overview  ...      revenue  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...  373554033.0
# 1  When siblings Judy and Peter discover an encha...  ...  262797249.0
# 2  A family wedding reignites the ancient feud be...  ...          0.0
# 3  Cheated on, mistreated and stepped on, the wom...  ...   81452156.0
# 4  Just when George Banks has recovered from his ...  ...   76578911.0
#
#   runtime                                   spoken_languages    status  \
# 0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2   101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3   127.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4   106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count  year
# 0                    Toy Story  False          7.7     5415.0  1995
# 1                      Jumanji  False          6.9     2413.0  1995
# 2             Grumpier Old Men  False          6.5       92.0  1995
# 3            Waiting to Exhale  False          6.1       34.0  1995
# 4  Father of the Bride Part II  False          5.7      173.0  1995
#
# [5 rows x 25 columns]

# %%
# Find the Movies that satisfy the criteria of 'm' and 'C' we calculated above. and also Reducing columns.
# Columns are: Title, Year of release, Vote_count, Average_vote, popularity, Genre and ratings
qualified = mdata[(mdata['vote_count'] >= m) & (mdata['vote_count'].notnull()) & 
                  (mdata['vote_average'].notnull())][['title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres']]
qualified['vote_count'] = qualified['vote_count'].astype('int')
qualified.shape
# Out:
# (2274, 6)

# %%
def weighted_rating(x):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
qualified['ratings'] = qualified.apply(weighted_rating, axis=1)
qualified
# Out:
#                                title  year  vote_count  vote_average  \
# 0                          Toy Story  1995        5415           7.7
# 1                            Jumanji  1995        2413           6.9
# 5                               Heat  1995        1886           7.7
# 9                          GoldenEye  1995        1194           6.6
# 15                            Casino  1995        1343           7.8
# ...                              ...   ...         ...           ...
# 44624        What Happened to Monday  2017         598           7.3
# 44632                  Atomic Blonde  2017         748           6.1
# 44678                        Dunkirk  2017        2712           7.5
# 44842  Transformers: The Last Knight  2017        1440           6.2
# 45014                 The Dark Tower  2017         688           5.7
#
#       popularity                                             genres   ratings
# 0      21.946943                        [Animation, Comedy, Family]  7.545529
# 1      17.015539                       [Adventure, Fantasy, Family]  6.704602
# 5      17.924927                   [Action, Crime, Drama, Thriller]  7.310561
# 9      14.686036                      [Adventure, Action, Thriller]  6.338269
# 15     10.137389                                     [Drama, Crime]  7.267137
# ...          ...                                                ...       ...
# 44624  60.581223                        [Science Fiction, Thriller]  6.592734
# 44632  14.455104                                 [Action, Thriller]  5.923098
# 44678  30.938854            [Action, Drama, History, Thriller, War]  7.240401
# 44842  39.186819     [Action, Science Fiction, Thriller, Adventure]  6.065263
# 45014  50.903593  [Action, Western, Science Fiction, Fantasy, Ho...  5.668362
#
# [2274 rows x 7 columns]

# %%
# Sorting based on rating and taking only top 250 Movies
qualified = qualified.sort_values('ratings', ascending=False).head(250)
qualified.head(20)
# Out:
#                                                title  year  vote_count  \
# 314                         The Shawshank Redemption  1994        8358
# 834                                    The Godfather  1972        6024
# 12481                                The Dark Knight  2008       12269
# 2843                                      Fight Club  1999        9678
# 292                                     Pulp Fiction  1994        8670
# 351                                     Forrest Gump  1994        8147
# 522                                 Schindler's List  1993        4436
# 23673                                       Whiplash  2014        4376
# 5481                                   Spirited Away  2001        3968
# 1154                         The Empire Strikes Back  1980        5998
# 15480                                      Inception  2010       14075
# 2211                               Life Is Beautiful  1997        3643
# 18465                               The Intouchables  2011        5410
# 22879                                   Interstellar  2014       11187
# 1178                          The Godfather: Part II  1974        3418
# 7000   The Lord of the Rings: The Return of the King  2003        8226
# 289                           Leon: The Professional  1994        4293
# 1152                 One Flew Over the Cuckoo's Nest  1975        3001
# 3030                                  The Green Mile  1999        4166
# 256                                        Star Wars  1977        6778
#
#        vote_average  popularity  \
# 314             8.5   51.645403
# 834             8.5   41.109264
# 12481           8.3  123.167259
# 2843            8.3   63.869599
# 292             8.3  140.950236
# 351             8.2   48.307194
# 522             8.3   41.725123
# 23673           8.3    64.29999
# 5481            8.3   41.048867
# 1154            8.2   19.470959
# 15480           8.1   29.108149
# 2211            8.3    39.39497
# 18465           8.2   16.086919
# 22879           8.1   32.213481
# 1178            8.3   36.629307
# 7000            8.1   29.324358
# 289             8.2   20.477329
# 1152            8.3   35.529554
# 3030            8.2    19.96678
# 256             8.1   42.149697
#
#                                                   genres   ratings
# 314                                       [Drama, Crime]  8.357746
# 834                                       [Drama, Crime]  8.306334
# 12481                   [Drama, Action, Crime, Thriller]  8.208376
# 2843                                             [Drama]  8.184899
# 292                                    [Thriller, Crime]  8.172155
# 351                             [Comedy, Drama, Romance]  8.069421
# 522                                [Drama, History, War]  8.061007
# 23673                                            [Drama]  8.058025
# 5481             [Fantasy, Adventure, Animation, Family]  8.035598
# 1154                [Adventure, Action, Science Fiction]  8.025793
# 15480  [Action, Thriller, Science Fiction, Mystery, A...  8.025763
# 2211                                     [Comedy, Drama]  8.014521
# 18465                                    [Drama, Comedy]  8.008265
# 22879                [Adventure, Drama, Science Fiction]  8.007315
# 1178                                      [Drama, Crime]  7.997846
# 7000                        [Adventure, Fantasy, Action]  7.975624
# 289                             [Thriller, Crime, Drama]  7.962958
# 1152                                             [Drama]  7.961165
# 3030                             [Fantasy, Drama, Crime]  7.956413
# 256                 [Adventure, Action, Science Fiction]  7.950652

# %%
s = mdata.apply(lambda x: pd.Series(x['genres']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'genre'
gen_df = mdata.drop('genres', axis=1).join(s)

# Above Step, Remove the genre column from mdata and converting the list of genre in 'Genre' Column into multiple rows.

# %%
gen_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 1      False                                                NaN  65000000
# ...      ...                                                ...       ...
# 45463  False                                                NaN         0
# 45463  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 1                                       NaN    8844  tt0113497
# ...                                     ...     ...        ...
# 45463                                   NaN   67758  tt0303758
# 45463                                   NaN   67758  tt0303758
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language       original_title  \
# 0                    en            Toy Story
# 0                    en            Toy Story
# 0                    en            Toy Story
# 1                    en              Jumanji
# 1                    en              Jumanji
# ...                 ...                  ...
# 45463                en             Betrayal
# 45463                en             Betrayal
# 45463                en             Betrayal
# 45464                en  Satana likuyushchiy
# 45465                en             Queerama
#
#                                                 overview popularity  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943  ...
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943  ...
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943  ...
# 1      When siblings Judy and Peter discover an encha...  17.015539  ...
# 1      When siblings Judy and Peter discover an encha...  17.015539  ...
# ...                                                  ...        ...  ...
# 45463  When one of her hits goes wrong, a professiona...   0.903007  ...
# 45463  When one of her hits goes wrong, a professiona...   0.903007  ...
# 45463  When one of her hits goes wrong, a professiona...   0.903007  ...
# 45464  In a small town live two brothers, one a minis...   0.003503  ...
# 45465  50 years after decriminalisation of homosexual...   0.163015  ...
#
#       runtime                                   spoken_languages    status  \
# 0        81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 0        81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 0        81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1       104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# ...       ...                                                ...       ...
# 45463    90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45463    90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45463    90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464    87.0                                                 []  Released
# 45465    75.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                          tagline             title  video  \
# 0                                            NaN         Toy Story  False
# 0                                            NaN         Toy Story  False
# 0                                            NaN         Toy Story  False
# 1      Roll the dice and unleash the excitement!           Jumanji  False
# 1      Roll the dice and unleash the excitement!           Jumanji  False
# ...                                          ...               ...    ...
# 45463                     A deadly game of wits.          Betrayal  False
# 45463                     A deadly game of wits.          Betrayal  False
# 45463                     A deadly game of wits.          Betrayal  False
# 45464                                        NaN  Satan Triumphant  False
# 45465                                        NaN          Queerama  False
#
#       vote_average vote_count  year      genre
# 0              7.7     5415.0  1995  Animation
# 0              7.7     5415.0  1995     Comedy
# 0              7.7     5415.0  1995     Family
# 1              6.9     2413.0  1995  Adventure
# 1              6.9     2413.0  1995    Fantasy
# ...            ...        ...   ...        ...
# 45463          3.8        6.0  2003     Action
# 45463          3.8        6.0  2003      Drama
# 45463          3.8        6.0  2003   Thriller
# 45464          0.0        0.0  1917        NaN
# 45465          0.0        0.0  2017        NaN
#
# [93548 rows x 25 columns]

# %%
# Doing all the things of votecounts and rating in this method, for a particular genre and returning top 250. (From mData)
def build_chart(genre, percentile=0.85):
    df = gen_df[gen_df['genre'] == genre]
    m = df[df.vote_count.notnull()].vote_count.astype('int').quantile(percentile)
    C = df[df.vote_average.notnull()]['vote_average'].mean()

    qualified = df[(df['vote_count'] >= m) & (df['vote_count'].notnull()) & 
                   (df['vote_average'].notnull())][['title', 'year', 'vote_count', 'vote_average', 'popularity']]
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    
    qualified['ratings'] = qualified.apply(lambda x: (x['vote_count']/(x['vote_count']+m) * x['vote_average'])
                                                       + (m/(m+x['vote_count']) * C), axis=1)
    qualified = qualified.sort_values('ratings', ascending=False).head(250)    
    return qualified

# %%
build_chart('Science Fiction')
# Out:
#                          title  year  vote_count  vote_average popularity  \
# 1154   The Empire Strikes Back  1980        5998           8.2  19.470959
# 15480                Inception  2010       14075           8.1  29.108149
# 22879             Interstellar  2014       11187           8.1  32.213481
# 256                  Star Wars  1977        6778           8.1  42.149697
# 1225        Back to the Future  1985        6239           8.0  25.778509
# ...                        ...   ...         ...           ...        ...
# 5325           Men in Black II  2002        3188           6.1  16.775716
# 17204         Attack the Block  2011         748           6.3    9.93263
# 12700      The Incredible Hulk  2008        3086           6.1  19.125537
# 4417             Short Circuit  1986         535           6.4  12.171218
# 288                   Outbreak  1995         522           6.4  13.676444
#
#         ratings
# 1154   8.071052
# 15480  8.045563
# 22879  8.031857
# 256    7.989310
# 1225   7.884509
# ...         ...
# 5325   6.038171
# 17204  6.036947
# 12700  6.036299
# 4417   6.033855
# 288    6.027946
#
# [250 rows x 6 columns]

# %% [markdown]
# # Content Based Recommendations

# %%
mdata = mdata.drop([19730, 29503, 35587])

# %%
links_small = pd.read_csv(r'./links_small.csv')
links_small = links_small[links_small['tmdbId'].notnull()]['tmdbId'].astype('int')
mdata.id = mdata.id.astype('int')
small_df = mdata[mdata['id'].isin(links_small)]
small_df.shape
# Out:
# (9099, 25)

# %% [markdown]
# ##### We will use Cosine Similarity to find similarity between 2 Movies numerically.

# %% [markdown]
# #### Movie Description Based Recommendation System

# %%
small_df.tagline = small_df.tagline.fillna('')
small_df.overview = small_df.overview.fillna('')
small_df['description'] = small_df.overview + small_df.tagline

# %% [markdown]
# #### TFID Vectorizer
# ##### Since we are using the TF-IDF Vectorizer, calculating the Dot Product will directly give us the Cosine Similarity Score.

# %%
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0.0, stop_words='english')
tfidf_matrix = tf.fit_transform(small_df['description'])
tfidf_matrix.shape
# Out:
# (9099, 268124)

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim[0]
# Out:
# array([1.        , 0.00680476, 0.        , ..., 0.        , 0.00344913,
#        0.        ])

# %%
small_df = small_df.reset_index()
titles = small_df['title']
indices = pd.Series(small_df.index, index=small_df['title'])

# %%
small_df
# Out:
#       index  adult                              belongs_to_collection  \
# 0         0  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1         1  False                                                NaN
# 2         2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3         3  False                                                NaN
# 4         4  False  {'id': 96871, 'name': 'Father of the Bride Col...
# ...     ...    ...                                                ...
# 9094  40224  False                                                NaN
# 9095  40503  False                                                NaN
# 9096  44821  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...
# 9097  44826  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...
# 9098  45265  False                                                NaN
#
#         budget                                             genres  \
# 0     30000000                        [Animation, Comedy, Family]
# 1     65000000                       [Adventure, Fantasy, Family]
# 2            0                                  [Romance, Comedy]
# 3     16000000                           [Comedy, Drama, Romance]
# 4            0                                           [Comedy]
# ...        ...                                                ...
# 9094  15000000  [Action, Adventure, Drama, Horror, Science Fic...
# 9095         0                               [Documentary, Music]
# 9096  16000000    [Adventure, Fantasy, Animation, Action, Family]
# 9097         0  [Adventure, Fantasy, Animation, Science Fictio...
# 9098         0                                    [Comedy, Drama]
#
#                                                homepage      id    imdb_id  \
# 0                  http://toystory.disney.com/toy-story     862  tt0114709
# 1                                                   NaN    8844  tt0113497
# 2                                                   NaN   15602  tt0113228
# 3                                                   NaN   31357  tt0114885
# 4                                                   NaN   11862  tt0113041
# ...                                                 ...     ...        ...
# 9094                                                NaN  315011  tt4262980
# 9095              http://www.thebeatlesliveproject.com/  391698  tt2531318
# 9096                  http://movies.warnerbros.com/pk3/   10991  tt0235679
# 9097  http://www.pokemon.com/us/movies/movie-pokemon...   12600  tt0287635
# 9098                                                NaN  265189  tt2121382
#
#      original_language                                     original_title  \
# 0                   en                                          Toy Story
# 1                   en                                            Jumanji
# 2                   en                                   Grumpier Old Men
# 3                   en                                  Waiting to Exhale
# 4                   en                        Father of the Bride Part II
# ...                ...                                                ...
# 9094                ja                                             シン・ゴジラ
# 9095                en  The Beatles: Eight Days a Week - The Touring Y...
# 9096                ja                               Pokémon 3: The Movie
# 9097                ja                     劇場版ポケットモンスター セレビィ 時を越えた遭遇（であい）
# 9098                sv                                             Turist
#
#       ... runtime                                   spoken_languages  \
# 0     ...    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1     ...   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2     ...   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3     ...   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4     ...   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...   ...     ...                                                ...
# 9094  ...   120.0  [{'iso_639_1': 'it', 'name': 'Italiano'}, {'is...
# 9095  ...    99.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9096  ...    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9097  ...    75.0               [{'iso_639_1': 'ja', 'name': '日本語'}]
# 9098  ...   118.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
#
#         status                                            tagline  \
# 0     Released
# 1     Released          Roll the dice and unleash the excitement!
# 2     Released  Still Yelling. Still Fighting. Still Ready for...
# 3     Released  Friends are the people who let you be yourself...
# 4     Released  Just When His World Is Back To Normal... He's ...
# ...        ...                                                ...
# 9094  Released                    A god incarnate. A city doomed.
# 9095  Released            The band you know. The story you don't.
# 9096  Released                      Pokémon: Spell of the Unknown
# 9097  Released
# 9098  Released
#
#                                                   title  video  vote_average  \
# 0                                             Toy Story  False           7.7
# 1                                               Jumanji  False           6.9
# 2                                      Grumpier Old Men  False           6.5
# 3                                     Waiting to Exhale  False           6.1
# 4                           Father of the Bride Part II  False           5.7
# ...                                                 ...    ...           ...
# 9094                                      Shin Godzilla  False           6.6
# 9095  The Beatles: Eight Days a Week - The Touring Y...  False           7.6
# 9096                      Pokémon: Spell of the Unknown  False           6.0
# 9097        Pokémon 4Ever: Celebi - Voice of the Forest  False           5.7
# 9098                                      Force Majeure  False           6.8
#
#       vote_count  year                                        description
# 0         5415.0  1995  Led by Woody, Andy's toys live happily in his ...
# 1         2413.0  1995  When siblings Judy and Peter discover an encha...
# 2           92.0  1995  A family wedding reignites the ancient feud be...
# 3           34.0  1995  Cheated on, mistreated and stepped on, the wom...
# 4          173.0  1995  Just when George Banks has recovered from his ...
# ...          ...   ...                                                ...
# 9094       152.0  2016  From the mind behind Evangelion comes a hit la...
# 9095        92.0  2016  The band stormed Europe in 1963, and, in 1964,...
# 9096       144.0  2000  When Molly Hale's sadness of her father's disa...
# 9097        82.0  2001  All your favorite Pokémon characters are back,...
# 9098       255.0  2014  While holidaying in the French Alps, a Swedish...
#
# [9099 rows x 27 columns]

# %%
def get_recommendations(title, cosine_sim):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:16]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

# %%
get_recommendations('Jumanji', cosine_sim)
# Out:
# 8889                        Pixels
# 8608       Guardians of the Galaxy
# 6392                    Stay Alive
# 8154                Wreck-It Ralph
# 3196            Dungeons & Dragons
# 8670                         Ouija
# 5356      Night of the Living Dead
# 8211              Would You Rather
# 6323                 Grandma's Boy
# 4082     The Giant Spider Invasion
# 5803               Comfort and Joy
# 1644                     Peter Pan
# 2080                      eXistenZ
# 6545             Sleeping Dogs Lie
# 6285    Zathura: A Space Adventure
# Name: title, dtype: object

# %%
get_recommendations('The Dark Knight', cosine_sim)
# Out:
# 7931                      The Dark Knight Rises
# 132                              Batman Forever
# 1113                             Batman Returns
# 8227    Batman: The Dark Knight Returns, Part 2
# 7565                 Batman: Under the Red Hood
# 524                                      Batman
# 7901                           Batman: Year One
# 2579               Batman: Mask of the Phantasm
# 2696                                        JFK
# 8165    Batman: The Dark Knight Returns, Part 1
# 6144                              Batman Begins
# 7933         Sherlock Holmes: A Game of Shadows
# 5511                            To End All Wars
# 4489                                      Q & A
# 7344                        Law Abiding Citizen
# Name: title, dtype: object

# %% [markdown]
# #### Genres, Cast and Keywords Based Recommendation System

# %%
credits = pd.read_csv(r'./credits.csv')
keywords = pd.read_csv(r'./keywords.csv')

# %%
keywords['id'] = keywords['id'].astype('int')
credits['id'] = credits['id'].astype('int')

# %%
md1 = mdata.merge(credits, on='id')
md1 = md1.merge(keywords, on='id')

# %%
small_df= md1[md1['id'].isin(links_small)]
small_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
#
#                                             overview  ...    status  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...  Released
# 1  When siblings Judy and Peter discover an encha...  ...  Released
# 2  A family wedding reignites the ancient feud be...  ...  Released
# 3  Cheated on, mistreated and stepped on, the wom...  ...  Released
# 4  Just when George Banks has recovered from his ...  ...  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average  vote_count  year  \
# 0                    Toy Story  False          7.7      5415.0  1995
# 1                      Jumanji  False          6.9      2413.0  1995
# 2             Grumpier Old Men  False          6.5        92.0  1995
# 3            Waiting to Exhale  False          6.1        34.0  1995
# 4  Father of the Bride Part II  False          5.7       173.0  1995
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
#                                             keywords
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
#
# [5 rows x 28 columns]

# %%
small_df.shape
# Out:
# (9219, 28)

# %%
def director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

small_df['director'] = small_df['crew'].apply(literal_eval).apply(lambda x: director(x))

# %%
small_df['cast'] = small_df['cast'].apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
small_df['cast'] = small_df['cast'].apply(lambda x: x[:3] if len(x) >=3 else x)

# %%
# Wrangling keywords
small_df['keywords'] = small_df['keywords'].apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
small_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45985  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...         0
# 46424  False                                                NaN         0
# 46425  False                                                NaN         0
# 46426  False                                                NaN         0
# 46427  False                                                NaN         0
#
#                                                   genres  \
# 0                            [Animation, Comedy, Family]
# 1                           [Adventure, Fantasy, Family]
# 2                                      [Romance, Comedy]
# 3                               [Comedy, Drama, Romance]
# 4                                               [Comedy]
# ...                                                  ...
# 45985  [Adventure, Fantasy, Animation, Science Fictio...
# 46424                                    [Comedy, Drama]
# 46425                                    [Comedy, Drama]
# 46426                                    [Comedy, Drama]
# 46427                                    [Comedy, Drama]
#
#                                                 homepage      id    imdb_id  \
# 0                   http://toystory.disney.com/toy-story     862  tt0114709
# 1                                                    NaN    8844  tt0113497
# 2                                                    NaN   15602  tt0113228
# 3                                                    NaN   31357  tt0114885
# 4                                                    NaN   11862  tt0113041
# ...                                                  ...     ...        ...
# 45985  http://www.pokemon.com/us/movies/movie-pokemon...   12600  tt0287635
# 46424                                                NaN  265189  tt2121382
# 46425                                                NaN  265189  tt2121382
# 46426                                                NaN  265189  tt2121382
# 46427                                                NaN  265189  tt2121382
#
#       original_language                  original_title  \
# 0                    en                       Toy Story
# 1                    en                         Jumanji
# 2                    en                Grumpier Old Men
# 3                    en               Waiting to Exhale
# 4                    en     Father of the Bride Part II
# ...                 ...                             ...
# 45985                ja  劇場版ポケットモンスター セレビィ 時を越えた遭遇（であい）
# 46424                sv                          Turist
# 46425                sv                          Turist
# 46426                sv                          Turist
# 46427                sv                          Turist
#
#                                                 overview  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...
# 1      When siblings Judy and Peter discover an encha...  ...
# 2      A family wedding reignites the ancient feud be...  ...
# 3      Cheated on, mistreated and stepped on, the wom...  ...
# 4      Just when George Banks has recovered from his ...  ...
# ...                                                  ...  ...
# 45985  All your favorite Pokémon characters are back,...  ...
# 46424  While holidaying in the French Alps, a Swedish...  ...
# 46425  While holidaying in the French Alps, a Swedish...  ...
# 46426  While holidaying in the French Alps, a Swedish...  ...
# 46427  While holidaying in the French Alps, a Swedish...  ...
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45985                                                NaN
# 46424                                                NaN
# 46425                                                NaN
# 46426                                                NaN
# 46427                                                NaN
#
#                                              title  video vote_average  \
# 0                                        Toy Story  False          7.7
# 1                                          Jumanji  False          6.9
# 2                                 Grumpier Old Men  False          6.5
# 3                                Waiting to Exhale  False          6.1
# 4                      Father of the Bride Part II  False          5.7
# ...                                            ...    ...          ...
# 45985  Pokémon 4Ever: Celebi - Voice of the Forest  False          5.7
# 46424                                Force Majeure  False          6.8
# 46425                                Force Majeure  False          6.8
# 46426                                Force Majeure  False          6.8
# 46427                                Force Majeure  False          6.8
#
#       vote_count  year                                               cast  \
# 0         5415.0  1995                [Tom Hanks, Tim Allen, Don Rickles]
# 1         2413.0  1995     [Robin Williams, Jonathan Hyde, Kirsten Dunst]
# 2           92.0  1995         [Walter Matthau, Jack Lemmon, Ann-Margret]
# 3           34.0  1995  [Whitney Houston, Angela Bassett, Loretta Devine]
# 4          173.0  1995         [Steve Martin, Diane Keaton, Martin Short]
# ...          ...   ...                                                ...
# 45985       82.0  2001  [Veronica Taylor, Rachael Lillis, Maddie Blaus...
# 46424      255.0  2014  [Lisa Loven Kongsli, Johannes Bah Kuhnke, Clar...
# 46425      255.0  2014  [Lisa Loven Kongsli, Johannes Bah Kuhnke, Clar...
# 46426      255.0  2014  [Lisa Loven Kongsli, Johannes Bah Kuhnke, Clar...
# 46427      255.0  2014  [Lisa Loven Kongsli, Johannes Bah Kuhnke, Clar...
#
#                                                     crew  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 45985  [{'credit_id': '52fe45049251416c75048e35', 'de...
# 46424  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46425  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46426  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46427  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
#
#                                                 keywords         director
# 0      [jealousy, toy, boy, friendship, friends, riva...    John Lasseter
# 1      [board game, disappearance, based on children'...     Joe Johnston
# 2      [fishing, best friend, duringcreditsstinger, o...    Howard Deutch
# 3      [based on novel, interracial relationship, sin...  Forest Whitaker
# 4      [baby, midlife crisis, confidence, aging, daug...    Charles Shyer
# ...                                                  ...              ...
# 45985                          [sequel, pokémon, celebi]  Kunihiko Yuyama
# 46424  [female nudity, dark comedy, family vacation, ...    Ruben Östlund
# 46425  [female nudity, dark comedy, family vacation, ...    Ruben Östlund
# 46426  [female nudity, dark comedy, family vacation, ...    Ruben Östlund
# 46427  [female nudity, dark comedy, family vacation, ...    Ruben Östlund
#
# [9219 rows x 29 columns]

# %%
# Strip Spaces and Convert to Lowercase
# and repeating director 3 times, to more weightage to director above all other crew.

small_df['cast'] = small_df['cast'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])
small_df['director'] = small_df['director'].astype('str').apply(lambda x: str.lower(x.replace(" ", "")))
small_df['director'] = small_df['director'].apply(lambda x: [x, x, x])

# %%
small_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45985  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...         0
# 46424  False                                                NaN         0
# 46425  False                                                NaN         0
# 46426  False                                                NaN         0
# 46427  False                                                NaN         0
#
#                                                   genres  \
# 0                            [Animation, Comedy, Family]
# 1                           [Adventure, Fantasy, Family]
# 2                                      [Romance, Comedy]
# 3                               [Comedy, Drama, Romance]
# 4                                               [Comedy]
# ...                                                  ...
# 45985  [Adventure, Fantasy, Animation, Science Fictio...
# 46424                                    [Comedy, Drama]
# 46425                                    [Comedy, Drama]
# 46426                                    [Comedy, Drama]
# 46427                                    [Comedy, Drama]
#
#                                                 homepage      id    imdb_id  \
# 0                   http://toystory.disney.com/toy-story     862  tt0114709
# 1                                                    NaN    8844  tt0113497
# 2                                                    NaN   15602  tt0113228
# 3                                                    NaN   31357  tt0114885
# 4                                                    NaN   11862  tt0113041
# ...                                                  ...     ...        ...
# 45985  http://www.pokemon.com/us/movies/movie-pokemon...   12600  tt0287635
# 46424                                                NaN  265189  tt2121382
# 46425                                                NaN  265189  tt2121382
# 46426                                                NaN  265189  tt2121382
# 46427                                                NaN  265189  tt2121382
#
#       original_language                  original_title  \
# 0                    en                       Toy Story
# 1                    en                         Jumanji
# 2                    en                Grumpier Old Men
# 3                    en               Waiting to Exhale
# 4                    en     Father of the Bride Part II
# ...                 ...                             ...
# 45985                ja  劇場版ポケットモンスター セレビィ 時を越えた遭遇（であい）
# 46424                sv                          Turist
# 46425                sv                          Turist
# 46426                sv                          Turist
# 46427                sv                          Turist
#
#                                                 overview  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...
# 1      When siblings Judy and Peter discover an encha...  ...
# 2      A family wedding reignites the ancient feud be...  ...
# 3      Cheated on, mistreated and stepped on, the wom...  ...
# 4      Just when George Banks has recovered from his ...  ...
# ...                                                  ...  ...
# 45985  All your favorite Pokémon characters are back,...  ...
# 46424  While holidaying in the French Alps, a Swedish...  ...
# 46425  While holidaying in the French Alps, a Swedish...  ...
# 46426  While holidaying in the French Alps, a Swedish...  ...
# 46427  While holidaying in the French Alps, a Swedish...  ...
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45985                                                NaN
# 46424                                                NaN
# 46425                                                NaN
# 46426                                                NaN
# 46427                                                NaN
#
#                                              title  video vote_average  \
# 0                                        Toy Story  False          7.7
# 1                                          Jumanji  False          6.9
# 2                                 Grumpier Old Men  False          6.5
# 3                                Waiting to Exhale  False          6.1
# 4                      Father of the Bride Part II  False          5.7
# ...                                            ...    ...          ...
# 45985  Pokémon 4Ever: Celebi - Voice of the Forest  False          5.7
# 46424                                Force Majeure  False          6.8
# 46425                                Force Majeure  False          6.8
# 46426                                Force Majeure  False          6.8
# 46427                                Force Majeure  False          6.8
#
#       vote_count  year                                               cast  \
# 0         5415.0  1995                   [tomhanks, timallen, donrickles]
# 1         2413.0  1995        [robinwilliams, jonathanhyde, kirstendunst]
# 2           92.0  1995           [waltermatthau, jacklemmon, ann-margret]
# 3           34.0  1995     [whitneyhouston, angelabassett, lorettadevine]
# 4          173.0  1995            [stevemartin, dianekeaton, martinshort]
# ...          ...   ...                                                ...
# 45985       82.0  2001   [veronicataylor, rachaellillis, maddieblaustein]
# 46424      255.0  2014  [lisalovenkongsli, johannesbahkuhnke, clarawet...
# 46425      255.0  2014  [lisalovenkongsli, johannesbahkuhnke, clarawet...
# 46426      255.0  2014  [lisalovenkongsli, johannesbahkuhnke, clarawet...
# 46427      255.0  2014  [lisalovenkongsli, johannesbahkuhnke, clarawet...
#
#                                                     crew  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 45985  [{'credit_id': '52fe45049251416c75048e35', 'de...
# 46424  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46425  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46426  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46427  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
#
#                                                 keywords  \
# 0      [jealousy, toy, boy, friendship, friends, riva...
# 1      [board game, disappearance, based on children'...
# 2      [fishing, best friend, duringcreditsstinger, o...
# 3      [based on novel, interracial relationship, sin...
# 4      [baby, midlife crisis, confidence, aging, daug...
# ...                                                  ...
# 45985                          [sequel, pokémon, celebi]
# 46424  [female nudity, dark comedy, family vacation, ...
# 46425  [female nudity, dark comedy, family vacation, ...
# 46426  [female nudity, dark comedy, family vacation, ...
# 46427  [female nudity, dark comedy, family vacation, ...
#
#                                                director
# 0            [johnlasseter, johnlasseter, johnlasseter]
# 1               [joejohnston, joejohnston, joejohnston]
# 2            [howarddeutch, howarddeutch, howarddeutch]
# 3      [forestwhitaker, forestwhitaker, forestwhitaker]
# 4            [charlesshyer, charlesshyer, charlesshyer]
# ...                                                 ...
# 45985  [kunihikoyuyama, kunihikoyuyama, kunihikoyuyama]
# 46424        [rubenöstlund, rubenöstlund, rubenöstlund]
# 46425        [rubenöstlund, rubenöstlund, rubenöstlund]
# 46426        [rubenöstlund, rubenöstlund, rubenöstlund]
# 46427        [rubenöstlund, rubenöstlund, rubenöstlund]
#
# [9219 rows x 29 columns]

# %%
# Further processing Keywords
kw = small_df.apply(lambda x: pd.Series(x['keywords']),axis=1).stack().reset_index(level=1, drop=True)
kw.name = 'keyword'
kw = kw.value_counts()
kw = kw[kw > 1]
kw
# Out:
# keyword
# independent film        610
# woman director          550
# murder                  399
# duringcreditsstinger    327
# based on novel          318
#                        ...
# boarder                   2
# social climbing           2
# covert operation          2
# prisoners                 2
# crystal                   2
# Name: count, Length: 6709, dtype: int64

# %%
def filter_keywords(keys):
    words = []
    for i in keys:
        if i in kw:
            words.append(i)
    return words

small_df.keywords = small_df['keywords'].apply(lambda x: filter_keywords(x))

# %%
small_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45985  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...         0
# 46424  False                                                NaN         0
# 46425  False                                                NaN         0
# 46426  False                                                NaN         0
# 46427  False                                                NaN         0
#
#                                                   genres  \
# 0                            [Animation, Comedy, Family]
# 1                           [Adventure, Fantasy, Family]
# 2                                      [Romance, Comedy]
# 3                               [Comedy, Drama, Romance]
# 4                                               [Comedy]
# ...                                                  ...
# 45985  [Adventure, Fantasy, Animation, Science Fictio...
# 46424                                    [Comedy, Drama]
# 46425                                    [Comedy, Drama]
# 46426                                    [Comedy, Drama]
# 46427                                    [Comedy, Drama]
#
#                                                 homepage      id    imdb_id  \
# 0                   http://toystory.disney.com/toy-story     862  tt0114709
# 1                                                    NaN    8844  tt0113497
# 2                                                    NaN   15602  tt0113228
# 3                                                    NaN   31357  tt0114885
# 4                                                    NaN   11862  tt0113041
# ...                                                  ...     ...        ...
# 45985  http://www.pokemon.com/us/movies/movie-pokemon...   12600  tt0287635
# 46424                                                NaN  265189  tt2121382
# 46425                                                NaN  265189  tt2121382
# 46426                                                NaN  265189  tt2121382
# 46427                                                NaN  265189  tt2121382
#
#       original_language                  original_title  \
# 0                    en                       Toy Story
# 1                    en                         Jumanji
# 2                    en                Grumpier Old Men
# 3                    en               Waiting to Exhale
# 4                    en     Father of the Bride Part II
# ...                 ...                             ...
# 45985                ja  劇場版ポケットモンスター セレビィ 時を越えた遭遇（であい）
# 46424                sv                          Turist
# 46425                sv                          Turist
# 46426                sv                          Turist
# 46427                sv                          Turist
#
#                                                 overview  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...
# 1      When siblings Judy and Peter discover an encha...  ...
# 2      A family wedding reignites the ancient feud be...  ...
# 3      Cheated on, mistreated and stepped on, the wom...  ...
# 4      Just when George Banks has recovered from his ...  ...
# ...                                                  ...  ...
# 45985  All your favorite Pokémon characters are back,...  ...
# 46424  While holidaying in the French Alps, a Swedish...  ...
# 46425  While holidaying in the French Alps, a Swedish...  ...
# 46426  While holidaying in the French Alps, a Swedish...  ...
# 46427  While holidaying in the French Alps, a Swedish...  ...
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45985                                                NaN
# 46424                                                NaN
# 46425                                                NaN
# 46426                                                NaN
# 46427                                                NaN
#
#                                              title  video vote_average  \
# 0                                        Toy Story  False          7.7
# 1                                          Jumanji  False          6.9
# 2                                 Grumpier Old Men  False          6.5
# 3                                Waiting to Exhale  False          6.1
# 4                      Father of the Bride Part II  False          5.7
# ...                                            ...    ...          ...
# 45985  Pokémon 4Ever: Celebi - Voice of the Forest  False          5.7
# 46424                                Force Majeure  False          6.8
# 46425                                Force Majeure  False          6.8
# 46426                                Force Majeure  False          6.8
# 46427                                Force Majeure  False          6.8
#
#       vote_count  year                                               cast  \
# 0         5415.0  1995                   [tomhanks, timallen, donrickles]
# 1         2413.0  1995        [robinwilliams, jonathanhyde, kirstendunst]
# 2           92.0  1995           [waltermatthau, jacklemmon, ann-margret]
# 3           34.0  1995     [whitneyhouston, angelabassett, lorettadevine]
# 4          173.0  1995            [stevemartin, dianekeaton, martinshort]
# ...          ...   ...                                                ...
# 45985       82.0  2001   [veronicataylor, rachaellillis, maddieblaustein]
# 46424      255.0  2014  [lisalovenkongsli, johannesbahkuhnke, clarawet...
# 46425      255.0  2014  [lisalovenkongsli, johannesbahkuhnke, clarawet...
# 46426      255.0  2014  [lisalovenkongsli, johannesbahkuhnke, clarawet...
# 46427      255.0  2014  [lisalovenkongsli, johannesbahkuhnke, clarawet...
#
#                                                     crew  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 45985  [{'credit_id': '52fe45049251416c75048e35', 'de...
# 46424  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46425  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46426  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46427  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
#
#                                                 keywords  \
# 0      [jealousy, toy, boy, friendship, friends, riva...
# 1      [board game, disappearance, based on children'...
# 2           [fishing, best friend, duringcreditsstinger]
# 3      [based on novel, interracial relationship, sin...
# 4      [baby, midlife crisis, confidence, aging, daug...
# ...                                                  ...
# 45985                          [sequel, pokémon, celebi]
# 46424  [female nudity, dark comedy, family vacation, ...
# 46425  [female nudity, dark comedy, family vacation, ...
# 46426  [female nudity, dark comedy, family vacation, ...
# 46427  [female nudity, dark comedy, family vacation, ...
#
#                                                director
# 0            [johnlasseter, johnlasseter, johnlasseter]
# 1               [joejohnston, joejohnston, joejohnston]
# 2            [howarddeutch, howarddeutch, howarddeutch]
# 3      [forestwhitaker, forestwhitaker, forestwhitaker]
# 4            [charlesshyer, charlesshyer, charlesshyer]
# ...                                                 ...
# 45985  [kunihikoyuyama, kunihikoyuyama, kunihikoyuyama]
# 46424        [rubenöstlund, rubenöstlund, rubenöstlund]
# 46425        [rubenöstlund, rubenöstlund, rubenöstlund]
# 46426        [rubenöstlund, rubenöstlund, rubenöstlund]
# 46427        [rubenöstlund, rubenöstlund, rubenöstlund]
#
# [9219 rows x 29 columns]

# %%
stemmer = SnowballStemmer('english')
small_df['keywords'] = small_df['keywords'].apply(lambda x: [stemmer.stem(i) for i in x])
small_df['keywords'] = small_df['keywords'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])

# %%
##### Create a column "soup" which is a string that contains all the metadata that we want to feed to our vectorizer (director, keywords, genre, actors, etc)

# %%
small_df['soup'] = small_df['cast'] + small_df['director'] + small_df['genres'] + small_df['keywords']
small_df['soup'] = small_df['soup'].apply(lambda x: ' '.join(x))

# %%
small_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
#
#                                             overview  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...
# 1  When siblings Judy and Peter discover an encha...  ...
# 2  A family wedding reignites the ancient feud be...  ...
# 3  Cheated on, mistreated and stepped on, the wom...  ...
# 4  Just when George Banks has recovered from his ...  ...
#
#                          title  video vote_average vote_count  year  \
# 0                    Toy Story  False          7.7     5415.0  1995
# 1                      Jumanji  False          6.9     2413.0  1995
# 2             Grumpier Old Men  False          6.5       92.0  1995
# 3            Waiting to Exhale  False          6.1       34.0  1995
# 4  Father of the Bride Part II  False          5.7      173.0  1995
#
#                                              cast  \
# 0                [tomhanks, timallen, donrickles]
# 1     [robinwilliams, jonathanhyde, kirstendunst]
# 2        [waltermatthau, jacklemmon, ann-margret]
# 3  [whitneyhouston, angelabassett, lorettadevine]
# 4         [stevemartin, dianekeaton, martinshort]
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
#                                             keywords  \
# 0  [jealousi, toy, boy, friendship, friend, rival...
# 1  [boardgam, disappear, basedonchildren'sbook, n...
# 2             [fish, bestfriend, duringcreditssting]
# 3  [basedonnovel, interracialrelationship, single...
# 4  [babi, midlifecrisi, confid, age, daughter, mo...
#
#                                            director  \
# 0        [johnlasseter, johnlasseter, johnlasseter]
# 1           [joejohnston, joejohnston, joejohnston]
# 2        [howarddeutch, howarddeutch, howarddeutch]
# 3  [forestwhitaker, forestwhitaker, forestwhitaker]
# 4        [charlesshyer, charlesshyer, charlesshyer]
#
#                                                 soup
# 0  tomhanks timallen donrickles johnlasseter john...
# 1  robinwilliams jonathanhyde kirstendunst joejoh...
# 2  waltermatthau jacklemmon ann-margret howarddeu...
# 3  whitneyhouston angelabassett lorettadevine for...
# 4  stevemartin dianekeaton martinshort charlesshy...
#
# [5 rows x 30 columns]

# %%
count = CountVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0.0, stop_words='english')
count_matrix = count.fit_transform(small_df['soup'])

# %%
cos_sim = cosine_similarity(count_matrix, count_matrix)

# %%
small_df = small_df.reset_index()
titles = small_df['title']
indices = pd.Series(small_df.index, index=small_df['title'])

# %%
get_recommendations('Jumanji', cos_sim)
# Out:
# 1624                             Honey, I Shrunk the Kids
# 5130                                              Hidalgo
# 500                                        The Pagemaster
# 1663                                        The Rocketeer
# 7489                                          The Wolfman
# 3653                                    Jurassic Park III
# 2012                                          October Sky
# 7883                   Captain America: The First Avenger
# 4909                                   The Cat in the Hat
# 7390                            Where the Wild Things Are
# 7494    Percy Jackson & the Olympians: The Lightning T...
# 5055                                            Peter Pan
# 6635                            Arthur and the Invisibles
# 6506                                  Night at the Museum
# 567                             James and the Giant Peach
# Name: title, dtype: object

# %%
get_recommendations('The Dark Knight', cos_sim)
# Out:
# 7991                 The Dark Knight Rises
# 6186                         Batman Begins
# 6587                          The Prestige
# 2077                             Following
# 7608                             Inception
# 4125                              Insomnia
# 3373                               Memento
# 8573                          Interstellar
# 7619            Batman: Under the Red Hood
# 1122                        Batman Returns
# 8899               Kidnapping Mr. Heineken
# 5907                              Thursday
# 1252                        Batman & Robin
# 9004    Batman v Superman: Dawn of Justice
# 4005                  The Long Good Friday
# Name: title, dtype: object

# %% [markdown]
# ##### One thing that we notice about our recommendation system is that it recommends movies regardless of ratings and popularity.
# ##### Therefore, we will add a mechanism to remove bad movies and return movies which are popular and have had a good critical response. We will calculate the weighted rating of each movie using IMDB's formula like we did in the Simple Recommender section.

# %%
def improved_recommendation(title, cosine_sim):   
    idx = indices[title]
    sim_score = list(enumerate(cosine_sim[idx]))
    sim_score = sorted(sim_score, key = lambda x:x[1], reverse = True)[1:51]
    movie_index = [i[0] for i in sim_score]
    
    movies = small_df.iloc[movie_index][['title', 'vote_average', 'vote_count', 'genres', 'cast', 'year']]
    m = movies[movies.vote_count.notnull()]['vote_count'].quantile(0.75)
    C = movies[movies.vote_average.notnull()]['vote_average'].mean()
    
    qualified = movies[(movies.vote_count >= m) & (movies.vote_count.notnull()) & (movies.vote_average.notnull())]
    qualified['Rating'] = qualified.apply(weighted_rating, axis=1)
    qualified = qualified.sort_values('Rating', ascending=False)[['title','Rating', 'genres', 'cast', 'year']]
    return qualified.head(10)

# %%
improved_recommendation('The Dark Knight', cos_sim)
# Out:
#                       title    Rating  \
# 7608              Inception  8.025763
# 8573           Interstellar  8.007315
# 3373                Memento  7.865950
# 6587           The Prestige  7.790919
# 7991  The Dark Knight Rises  7.511303
# 6186          Batman Begins  7.397206
# 7539               Kick-Ass  6.975874
# 524                  Batman  6.767469
# 1122         Batman Returns  6.400889
# 8423             Kick-Ass 2  6.190772
#
#                                                  genres  \
# 7608  [Action, Thriller, Science Fiction, Mystery, A...
# 8573                [Adventure, Drama, Science Fiction]
# 3373                                [Mystery, Thriller]
# 6587                         [Drama, Mystery, Thriller]
# 7991                   [Action, Crime, Drama, Thriller]
# 6186                             [Action, Crime, Drama]
# 7539                                    [Action, Crime]
# 524                                   [Fantasy, Action]
# 1122                                  [Action, Fantasy]
# 8423                         [Action, Adventure, Crime]
#
#                                                    cast  year
# 7608  [leonardodicaprio, josephgordon-levitt, ellenp...  2010
# 8573  [matthewmcconaughey, jessicachastain, annehath...  2014
# 3373        [guypearce, carrie-annemoss, joepantoliano]  2000
# 6587         [hughjackman, christianbale, michaelcaine]  2006
# 7991          [christianbale, michaelcaine, garyoldman]  2012
# 6186          [christianbale, michaelcaine, liamneeson]  2005
# 7539  [aarontaylor-johnson, chloëgracemoretz, christ...  2010
# 524         [jacknicholson, michaelkeaton, kimbasinger]  1989
# 1122     [michaelkeaton, dannydevito, michellepfeiffer]  1992
# 8423  [aarontaylor-johnson, chloëgracemoretz, christ...  2013

# %%
improved_recommendation('Jumanji', cos_sim)
# Out:
#                                              title    Rating  \
# 5420      Harry Potter and the Prisoner of Azkaban  7.560377
# 3824      Harry Potter and the Philosopher's Stone  7.392850
# 6322           Harry Potter and the Goblet of Fire  7.368104
# 7706  Harry Potter and the Deathly Hallows: Part 1  7.367031
# 4342       Harry Potter and the Chamber of Secrets  7.279172
# 6765     Harry Potter and the Order of the Phoenix  7.272540
# 7305        Harry Potter and the Half-Blood Prince  7.268240
# 521                                        Aladdin  7.203182
# 7883            Captain America: The First Avenger  6.543993
# 6506                           Night at the Museum  6.299705
#
#                                                  genres  \
# 5420                       [Adventure, Fantasy, Family]
# 3824                       [Adventure, Fantasy, Family]
# 6322                       [Adventure, Fantasy, Family]
# 7706                       [Adventure, Fantasy, Family]
# 4342                       [Adventure, Fantasy, Family]
# 6765              [Adventure, Fantasy, Family, Mystery]
# 7305                       [Adventure, Fantasy, Family]
# 521   [Animation, Family, Comedy, Adventure, Fantasy...
# 7883               [Action, Adventure, Science Fiction]
# 6506       [Action, Adventure, Comedy, Family, Fantasy]
#
#                                             cast  year
# 5420  [danielradcliffe, rupertgrint, emmawatson]  2004
# 3824  [danielradcliffe, rupertgrint, emmawatson]  2001
# 6322  [danielradcliffe, rupertgrint, emmawatson]  2005
# 7706  [danielradcliffe, emmawatson, rupertgrint]  2010
# 4342  [danielradcliffe, rupertgrint, emmawatson]  2002
# 6765  [danielradcliffe, rupertgrint, emmawatson]  2007
# 7305  [danielradcliffe, rupertgrint, emmawatson]  2009
# 521   [scottweinger, robinwilliams, lindalarkin]  1992
# 7883    [chrisevans, hugoweaving, tommyleejones]  2011
# 6506       [benstiller, jakecherry, carlagugino]  2006

# %%
improved_recommendation('Iron Man', cos_sim)
# Out:
#                                     title    Rating  \
# 8680              Guardians of the Galaxy  7.805216
# 8590  Captain America: The Winter Soldier  7.463801
# 8622           X-Men: Days of Future Past  7.376051
# 7929                         The Avengers  7.337808
# 8839                             Deadpool  7.334897
# 8836              Avengers: Age of Ultron  7.200586
# 8840           Captain America: Civil War  7.018554
# 8837                              Ant-Man  6.907211
# 8348                           Iron Man 3  6.745349
# 7883   Captain America: The First Avenger  6.543993
#
#                                              genres  \
# 8680           [Action, Science Fiction, Adventure]
# 8590           [Action, Adventure, Science Fiction]
# 8622  [Action, Adventure, Fantasy, Science Fiction]
# 7929           [Science Fiction, Action, Adventure]
# 8839                    [Action, Adventure, Comedy]
# 8836           [Action, Adventure, Science Fiction]
# 8840           [Adventure, Action, Science Fiction]
# 8837           [Science Fiction, Action, Adventure]
# 8348           [Action, Adventure, Science Fiction]
# 7883           [Action, Adventure, Science Fiction]
#
#                                                   cast  year
# 8680            [chrispratt, zoesaldana, davebautista]  2014
# 8590  [chrisevans, samuell.jackson, scarlettjohansson]  2014
# 8622     [hughjackman, jamesmcavoy, michaelfassbender]  2014
# 7929        [robertdowneyjr., chrisevans, markruffalo]  2012
# 8839          [ryanreynolds, morenabaccarin, edskrein]  2016
# 8836    [robertdowneyjr., chrishemsworth, markruffalo]  2015
# 8840  [chrisevans, robertdowneyjr., scarlettjohansson]  2016
# 8837       [paulrudd, michaeldouglas, evangelinelilly]  2015
# 8348     [robertdowneyjr., gwynethpaltrow, doncheadle]  2013
# 7883          [chrisevans, hugoweaving, tommyleejones]  2011

# %% [markdown]
# # Collaborative based Filtering Recommendations System
# ##### Collaborative Filtering is based on the idea that users similar to a me can be used to predict how much I will like a particular product or service those users have used/experienced but I have not.
# ##### User based filtering
# ###### - These systems recommend products to a user that similar users have liked. For measuring the similarity between two users we can either use pearson correlation or cosine similarity.
# ##### Item Based Collaborative Filtering
# ###### - Instead of measuring the similarity between users, the item-based CF recommends items based on their similarity with the items that the target user rated. Likewise, the similarity can be computed with Pearson Correlation or Cosine Similarity.
#
# #### We will use Singular Value Decomposition(SVD) library to minimise RMSE for recommendations.

# %%
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate

reader = Reader()

# %%
ratings = pd.read_csv(r'./ratings_small.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
# convert Pandas dataframe to surpise dataset for recommendations.
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)

# %%
svd = SVD()
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8957  0.8946  0.9008  0.8929  0.8981  0.8964  0.0028
# MAE (testset)     0.6879  0.6876  0.6943  0.6879  0.6917  0.6899  0.0027
# Fit time          0.31    0.31    0.31    0.30    0.31    0.31    0.00
# Test time         0.04    0.04    0.04    0.09    0.04    0.05    0.02
# {'test_rmse': array([0.8957411 , 0.89456811, 0.90078144, 0.89288433, 0.8981465 ]),
#  'test_mae': array([0.68785822, 0.68761692, 0.69431682, 0.68791257, 0.69169849]),
#  'fit_time': (0.3056979179382324,
#   0.3077559471130371,
#   0.3138549327850342,
#   0.3020479679107666,
#   0.3121800422668457),
#  'test_time': (0.04407620429992676,
#   0.042482852935791016,
#   0.04102301597595215,
#   0.09145498275756836,
#   0.040960073471069336)}

# %%
# data.build_full_trainset() converts the dataset(data) into a Surprise Trainset object
# svd.fit(trainset) : trains the SVD model on the training data.
trainset = data.build_full_trainset()
svd.fit(trainset)

# %%
# Lets check rating and reviews given by userid 100
ratings[ratings['userId'] == 100]
# Out:
#        userId  movieId  rating  timestamp
# 15273     100        1     4.0  854193977
# 15274     100        3     4.0  854194024
# 15275     100        6     3.0  854194023
# 15276     100        7     3.0  854194024
# 15277     100       25     4.0  854193977
# 15278     100       32     5.0  854193977
# 15279     100       52     3.0  854194056
# 15280     100       62     3.0  854193977
# 15281     100       86     3.0  854194208
# 15282     100       88     2.0  854194208
# 15283     100       95     3.0  854193977
# 15284     100      135     3.0  854194086
# 15285     100      141     3.0  854193977
# 15286     100      608     4.0  854194024
# 15287     100      648     3.0  854193977
# 15288     100      661     3.0  854194086
# 15289     100      708     3.0  854194056
# 15290     100      733     3.0  854194024
# 15291     100      736     3.0  854193977
# 15292     100      745     4.0  854194208
# 15293     100      780     3.0  854193977
# 15294     100      786     3.0  854194056
# 15295     100      802     4.0  854194111
# 15296     100     1073     5.0  854194056
# 15297     100     1356     4.0  854194086

# %%
# This line predicts the rating that User 100 would give to Movie 302 using the trained SVD model.
svd.predict(100, 302)
# Out:
# Prediction(uid=100, iid=302, r_ui=None, est=3.228487870817355, details={'was_impossible': False})

# %% [markdown]
# # Hybrid Recommendation
#
# #### We will build simple hybrod recommendation system that brings together both content and collaborative filtering based engine.
# ##### Input: USERID and MOVIE TITLE
# ##### Output: Similar movies sorted on the basis of expected ratings by that particular user.

# %%
id_map = pd.read_csv(r'./links_small.csv')
id_map = id_map[['movieId', 'tmdbId']].dropna()
id_map['tmdbId'] = id_map['tmdbId'].astype('int')
id_map.columns = ['movieId', 'id']
id_map = id_map.merge(small_df[['title', 'id']], on='id').set_index('title')

# %%
indices_map = id_map.set_index('id')

# %%
def hybrid(userId, title, cosine_sim):
    idx = indices[title]
    tmdbId = id_map.loc[title]['id']
    # print(idx)
    movie_id = id_map.loc[title]['movieId']
    
    sim_scores = list(enumerate(cosine_sim[int(idx)]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)[1:51]
    movie_indices = [i[0] for i in sim_scores]
    
    movies = small_df.iloc[movie_indices][['title', 'genres', 'vote_count', 'vote_average', 'year', 'id']]
    movies['est_rating'] = movies['id'].apply(lambda x: svd.predict(userId, indices_map.loc[x]['movieId']).est)
    movies = movies.sort_values('est_rating', ascending=False)
    return movies.head(10)

# %%
hybrid(10, 'Journey 2: The Mysterious Island', cos_sim)
# Out:
#                                     title  \
# 958               The Empire Strikes Back
# 232                             Star Wars
# 8837                              Ant-Man
# 8680              Guardians of the Galaxy
# 8590  Captain America: The Winter Soldier
# 6680                                 Next
# 4194                           Rollerball
# 971                    Return of the Jedi
# 8836              Avengers: Age of Ultron
# 8941                          San Andreas
#
#                                     genres  vote_count  vote_average  year  \
# 958   [Adventure, Action, Science Fiction]      5998.0           8.2  1980
# 232   [Adventure, Action, Science Fiction]      6778.0           8.1  1977
# 8837  [Science Fiction, Action, Adventure]      6029.0           7.0  2015
# 8680  [Action, Science Fiction, Adventure]     10014.0           7.9  2014
# 8590  [Action, Adventure, Science Fiction]      5881.0           7.6  2014
# 6680   [Action, Science Fiction, Thriller]       880.0           5.9  2007
# 4194  [Adventure, Action, Science Fiction]       115.0           6.0  1975
# 971   [Adventure, Action, Science Fiction]      4763.0           7.9  1983
# 8836  [Action, Adventure, Science Fiction]      6908.0           7.3  2015
# 8941             [Action, Drama, Thriller]      3017.0           6.0  2015
#
#           id  est_rating
# 958     1891    4.193405
# 232       11    4.165456
# 8837  102899    3.987863
# 8680  118340    3.947313
# 8590  100402    3.914631
# 6680    1738    3.862074
# 4194   11484    3.804226
# 971     1892    3.797341
# 8836   99861    3.751558
# 8941  254128    3.718257

# %%
hybrid(100, 'Avatar', cos_sim)
# Out:
#                                    title  \
# 999                       The Terminator
# 1229                   The Fifth Element
# 1368                             Titanic
# 962                               Aliens
# 8357             Star Trek Into Darkness
# 2826                            Predator
# 1613  Darby O'Gill and the Little People
# 3983         Vampire Hunter D: Bloodlust
# 3173                    The Time Machine
# 1660          Return from Witch Mountain
#
#                                                  genres  vote_count  \
# 999                 [Action, Thriller, Science Fiction]      4208.0
# 1229  [Adventure, Fantasy, Action, Thriller, Science...      3962.0
# 1368                         [Drama, Romance, Thriller]      7770.0
# 962         [Horror, Action, Thriller, Science Fiction]      3282.0
# 8357               [Action, Adventure, Science Fiction]      4479.0
# 2826     [Science Fiction, Action, Adventure, Thriller]      2129.0
# 1613      [Adventure, Fantasy, Science Fiction, Family]        35.0
# 3983  [Action, Adventure, Animation, Fantasy, Horror...        92.0
# 3173  [Thriller, Adventure, Fantasy, Science Fiction...       217.0
# 1660      [Adventure, Fantasy, Science Fiction, Family]        38.0
#
#       vote_average  year     id  est_rating
# 999            7.4  1984    218    3.801506
# 1229           7.3  1997     18    3.795875
# 1368           7.5  1997    597    3.712107
# 962            7.7  1986    679    3.687926
# 8357           7.4  2013  54138    3.676456
# 2826           7.3  1987    106    3.646761
# 1613           6.7  1959  18887    3.642457
# 3983           7.0  2000  15999    3.613416
# 3173           7.5  1960   2134    3.561398
# 1660           5.6  1978  14822    3.533100

# %%
hybrid(1, 'Avatar', cos_sim)
# Out:
#                                        title  \
# 522               Terminator 2: Judgment Day
# 999                           The Terminator
# 962                                   Aliens
# 8357                 Star Trek Into Darkness
# 344                                True Lies
# 1660              Return from Witch Mountain
# 8984                           Suicide Squad
# 8401  Justice League: The Flashpoint Paradox
# 910                                The Abyss
# 7055                       Mutant Chronicles
#
#                                                  genres  vote_count  \
# 522                 [Action, Thriller, Science Fiction]      4274.0
# 999                 [Action, Thriller, Science Fiction]      4208.0
# 962         [Horror, Action, Thriller, Science Fiction]      3282.0
# 8357               [Action, Adventure, Science Fiction]      4479.0
# 344                                  [Action, Thriller]      1138.0
# 1660      [Adventure, Fantasy, Science Fiction, Family]        38.0
# 8984  [Action, Adventure, Crime, Fantasy, Science Fi...      7717.0
# 8401  [Fantasy, Science Fiction, Animation, Action, ...       458.0
# 910      [Adventure, Action, Thriller, Science Fiction]       822.0
# 7055       [Action, Adventure, Horror, Science Fiction]       142.0
#
#       vote_average  year      id  est_rating
# 522            7.7  1991     280    3.319828
# 999            7.4  1984     218    3.134059
# 962            7.7  1986     679    3.113002
# 8357           7.4  2013   54138    2.955264
# 344            6.8  1994   36955    2.911642
# 1660           5.6  1978   14822    2.907418
# 8984           5.9  2016  297761    2.878399
# 8401           7.3  2013  183011    2.875250
# 910            7.1  1989    2756    2.865143
# 7055           5.1  2008   13256    2.863256
